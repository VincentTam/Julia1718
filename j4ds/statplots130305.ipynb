# %%
using RDatasets, Plots, StatPlots
plotlyjs()
# Out:
# Plots.PlotlyJSBackend()

# %% [markdown]
# More plots on [StatPlots's README](https://github.com/JuliaPlots/StatPlots.jl).

# %%
sleep = dataset("lme4", "sleepstudy")
# Out:
# WARNING: imported binding for sleep overwritten in module Main
# 180×3 DataFrames.DataFrame
# │ Row │ Reaction │ Days │ Subject │
# ├─────┼──────────┼──────┼─────────┤
# │ 1   │ 249.56   │ 0    │ 308     │
# │ 2   │ 258.705  │ 1    │ 308     │
# │ 3   │ 250.801  │ 2    │ 308     │
# │ 4   │ 321.44   │ 3    │ 308     │
# │ 5   │ 356.852  │ 4    │ 308     │
# │ 6   │ 414.69   │ 5    │ 308     │
# │ 7   │ 382.204  │ 6    │ 308     │
# │ 8   │ 290.149  │ 7    │ 308     │
# │ 9   │ 430.585  │ 8    │ 308     │
# │ 10  │ 466.353  │ 9    │ 308     │
# │ 11  │ 222.734  │ 0    │ 309     │
# ⋮
# │ 169 │ 350.781  │ 8    │ 371     │
# │ 170 │ 369.469  │ 9    │ 371     │
# │ 171 │ 269.412  │ 0    │ 372     │
# │ 172 │ 273.474  │ 1    │ 372     │
# │ 173 │ 297.597  │ 2    │ 372     │
# │ 174 │ 310.632  │ 3    │ 372     │
# │ 175 │ 287.173  │ 4    │ 372     │
# │ 176 │ 329.608  │ 5    │ 372     │
# │ 177 │ 334.482  │ 6    │ 372     │
# │ 178 │ 343.22   │ 7    │ 372     │
# ...

# %%
@df sleep scatter(:Days, :Reaction)
# Out:
# <div id="9e7a684c-335f-4f4c-9ae7-6b1ac574841c" class="plotly-graph-div"></div>
#
# <script>
#     (function() {
# ...

# %%
@df sleep histogram(:Reaction, bins=30)
# Out:
# <div id="08020aa9-81d8-48d9-a753-820ed7c55e5d" class="plotly-graph-div"></div>
#
# <script>
#     (function() {
# ...

# %%
@df sleep density(:Reaction, group = :Subject)
# Out:
# <div id="8b2974c9-7b0a-435b-910c-66ede276da5c" class="plotly-graph-div"></div>
#
# <script>
#     (function() {
# ...
