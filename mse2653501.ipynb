# %%
using Plots
# Out:
# INFO: Recompiling stale cache file C:\Users\Owner\.julia\lib\v0.6\StatsBase.ji for module StatsBase.
# WARNING: Method definition midpoints(AbstractArray{T, 1} where T) in module Base at deprecated.jl:56 overwritten in module StatsBase at C:\Users\Owner\.julia\v0.6\StatsBase\src\hist.jl:533.
# WARNING: Method definition midpoints(Base.Range{T} where T) in module Base at deprecated.jl:56 overwritten in module StatsBase at C:\Users\Owner\.julia\v0.6\StatsBase\src\hist.jl:535.
# WARNING: Method definition midpoints(Base.Range{T} where T) in module Base at deprecated.jl:56 overwritten in module StatsBase at C:\Users\Owner\.julia\v0.6\StatsBase\src\hist.jl:535.
# WARNING: Method definition midpoints(AbstractArray{T, 1} where T) in module Base at deprecated.jl:56 overwritten in module StatsBase at C:\Users\Owner\.julia\v0.6\StatsBase\src\hist.jl:533.
# INFO: Recompiling stale cache file C:\Users\Owner\.julia\lib\v0.6\Plots.ji for module Plots.
# ...

# %%
x = linspace(0, 5, 501)
f(x) = exp(-x)
plot(x,f.(f.(x)))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0000">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0001">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0000)" points="
# 32.2221,375.813 580.315,375.813 580.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0002">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# ...

# %%
savefig("myplot.png")
